# %%
import numpy as np
import datetime as dt
from pathlib import Path
import os
import pandas as pd
import alpaca_trade_api as tradeapi
from dotenv import load_dotenv
load_dotenv()

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")

api = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2"
)

# %%
# Switch to Yahoo
timeframe = "1D"


start_date = pd.Timestamp("2000-11-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2020-11-01", tz="America/New_York").isoformat()


ticker = ['XLE', 'XLF', 'XLK', 'XLV']

df_ticker = api.get_barset(
    ticker,
    timeframe,
    start=start_date,
    end=end_date,
    limit = 1000,
).df

# %%
gov_data = pd.read_csv('https://raw.githubusercontent.com/MikeGruz/us-gov-control-historical/master/us_government_control_1857-2016.csv')
gov_data
# Out:
#     id  congress  year_start  year_end  senate_total  senate_dems  \
# 0    1        35        1857      1859            64           39
# 1    2        36        1859      1861            66           38
# 2    3        37        1861      1863            50           11
# 3    4        38        1863      1865            51           12
# 4    5        39        1865      1867            52           10
# ..  ..       ...         ...       ...           ...          ...
# 75  76       110        2007      2009           100           49
# 76  77       111        2009      2011           100           57
# 77  78       112        2011      2013           100           51
# 78  79       113        2013      2015           100           53
# 79  80       114        2015      2017           100           44
#
#     senate_dem_perc  senate_reps  senate_rep_perc  senate_others  ...  \
# 0          0.609375           20         0.312500              5  ...
# ...

# %%
gov_data.drop(labels = range(0,70), axis = 0)
# Out:
#     id  congress  year_start  year_end  senate_total  senate_dems  \
# 70  71       105        1997      1999           100           45
# 71  72       106        1999      2001           100           45
# 72  73       107        2001      2003           100           50
# 73  74       108        2003      2005           100           48
# 74  75       109        2005      2007           100           44
# 75  76       110        2007      2009           100           49
# 76  77       111        2009      2011           100           57
# 77  78       112        2011      2013           100           51
# 78  79       113        2013      2015           100           53
# 79  80       114        2015      2017           100           44
#
#     senate_dem_perc  senate_reps  senate_rep_perc  senate_others  ...  \
# 70             0.45           55             0.55              0  ...
# 71             0.45           55             0.55              0  ...
# ...
